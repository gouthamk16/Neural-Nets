# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dense, Dropout, BatchNormalization, Flatten
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from keras.utils import to_categorical
from keras.datasets import cifar10

# %%
(train_images, train_labels),(test_images, test_labels) = cifar10.load_data()
print(train_images.shape)
print(test_images.shape)
print(len(train_labels))
print(len(test_labels))
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# (50000, 32, 32, 3)
# (10000, 32, 32, 3)
# 50000
# 10000

# %%
train_images=train_images.reshape((train_images.shape[0],32,32,3))
test_images=test_images.reshape((test_images.shape[0],32,32,3))

# %%
train_labels=to_categorical(train_labels)
test_labels=to_categorical(test_labels)

# %%
from keras.optimizers import Adam, RMSprop, SGD
from keras.losses import CategoricalCrossentropy
from keras.callbacks import ReduceLROnPlateau
from keras.regularizers import l2

model=Sequential()
model.add(Conv2D(32, (3,3), activation='relu', padding='same', input_shape=(32,32,3), kernel_regularizer=l2(0.001)))
model.add(MaxPooling2D(2,2))
model.add(BatchNormalization())
model.add(Conv2D(64, (2,2), activation='relu', padding='same', kernel_regularizer=l2(0.001)))
model.add(MaxPooling2D(2,2))
model.add(BatchNormalization())
model.add(Conv2D(128, (2,2), activation='relu', padding='same', kernel_regularizer=l2(0.001)))
model.add(MaxPooling2D(2,2))
model.add(BatchNormalization())
model.add(Conv2D(256, (2,2), activation='relu', padding='same', kernel_regularizer=l2(0.001)))
model.add(MaxPooling2D(2,2))
model.add(BatchNormalization())
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(10, activation='softmax'))

reduce_lr=ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3, min_lr=1e-7)

model.compile(optimizer=Adam(learning_rate=0.001), loss=CategoricalCrossentropy(from_logits=False), metrics=['accuracy'])
history=model.fit(train_images, train_labels, epochs=50, validation_data=(test_images, test_labels), batch_size=64, callbacks=[reduce_lr])
# Out:
# Epoch 1/50
#  28/782 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.1596 - loss: 2.9252
# W0000 00:00:1714654320.951883     116 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.3149 - loss: 2.2060
# W0000 00:00:1714654329.314038     117 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# W0000 00:00:1714654330.452442     118 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 19s 13ms/step - accuracy: 0.3150 - loss: 2.2056 - val_accuracy: 0.4501 - val_loss: 1.9122 - learning_rate: 0.0010
# Epoch 2/50
#  28/782 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.5241 - loss: 1.5827
# W0000 00:00:1714654331.383589     117 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.5439 - loss: 1.5366 - val_accuracy: 0.5847 - val_loss: 1.4242 - learning_rate: 0.0010
# Epoch 3/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.6311 - loss: 1.2977 - val_accuracy: 0.6341 - val_loss: 1.2597 - learning_rate: 0.0010
# Epoch 4/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.6832 - loss: 1.1579 - val_accuracy: 0.6874 - val_loss: 1.1416 - learning_rate: 0.0010
# Epoch 5/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7180 - loss: 1.0635 - val_accuracy: 0.5961 - val_loss: 1.4698 - learning_rate: 0.0010
# Epoch 6/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7453 - loss: 1.0058 - val_accuracy: 0.7243 - val_loss: 1.0690 - learning_rate: 0.0010
# Epoch 7/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7592 - loss: 0.9803 - val_accuracy: 0.7239 - val_loss: 1.0933 - learning_rate: 0.0010
# Epoch 8/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7759 - loss: 0.9396 - val_accuracy: 0.7102 - val_loss: 1.1659 - learning_rate: 0.0010
# Epoch 9/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7918 - loss: 0.9080 - val_accuracy: 0.7482 - val_loss: 1.0581 - learning_rate: 0.0010
# Epoch 10/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7969 - loss: 0.8986 - val_accuracy: 0.7209 - val_loss: 1.1352 - learning_rate: 0.0010
# Epoch 11/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.8080 - loss: 0.8842 - val_accuracy: 0.7171 - val_loss: 1.1632 - learning_rate: 0.0010
# Epoch 12/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8171 - loss: 0.8615 - val_accuracy: 0.7330 - val_loss: 1.1098 - learning_rate: 0.0010
# Epoch 13/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8606 - loss: 0.7262 - val_accuracy: 0.7976 - val_loss: 0.9309 - learning_rate: 2.0000e-04
# Epoch 14/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9001 - loss: 0.5877 - val_accuracy: 0.8045 - val_loss: 0.9167 - learning_rate: 2.0000e-04
# Epoch 15/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9146 - loss: 0.5222 - val_accuracy: 0.8051 - val_loss: 0.9630 - learning_rate: 2.0000e-04
# Epoch 16/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9292 - loss: 0.4719 - val_accuracy: 0.8024 - val_loss: 0.9916 - learning_rate: 2.0000e-04
# Epoch 17/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9347 - loss: 0.4394 - val_accuracy: 0.7971 - val_loss: 1.0129 - learning_rate: 2.0000e-04
# Epoch 18/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9500 - loss: 0.3943 - val_accuracy: 0.8072 - val_loss: 1.0100 - learning_rate: 4.0000e-05
# Epoch 19/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9562 - loss: 0.3684 - val_accuracy: 0.8081 - val_loss: 1.0385 - learning_rate: 4.0000e-05
# Epoch 20/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9617 - loss: 0.3520 - val_accuracy: 0.8117 - val_loss: 1.0562 - learning_rate: 4.0000e-05
# Epoch 21/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9647 - loss: 0.3385 - val_accuracy: 0.8111 - val_loss: 1.0606 - learning_rate: 8.0000e-06
# Epoch 22/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9641 - loss: 0.3392 - val_accuracy: 0.8116 - val_loss: 1.0677 - learning_rate: 8.0000e-06
# Epoch 23/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9661 - loss: 0.3329 - val_accuracy: 0.8121 - val_loss: 1.0748 - learning_rate: 8.0000e-06
# Epoch 24/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9650 - loss: 0.3332 - val_accuracy: 0.8118 - val_loss: 1.0771 - learning_rate: 1.6000e-06
# Epoch 25/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9667 - loss: 0.3322 - val_accuracy: 0.8119 - val_loss: 1.0768 - learning_rate: 1.6000e-06
# Epoch 26/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9644 - loss: 0.3329 - val_accuracy: 0.8120 - val_loss: 1.0773 - learning_rate: 1.6000e-06
# Epoch 27/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9666 - loss: 0.3304 - val_accuracy: 0.8121 - val_loss: 1.0787 - learning_rate: 3.2000e-07
# Epoch 28/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9671 - loss: 0.3293 - val_accuracy: 0.8120 - val_loss: 1.0771 - learning_rate: 3.2000e-07
# Epoch 29/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9676 - loss: 0.3303 - val_accuracy: 0.8115 - val_loss: 1.0788 - learning_rate: 3.2000e-07
# Epoch 30/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9689 - loss: 0.3242 - val_accuracy: 0.8121 - val_loss: 1.0776 - learning_rate: 1.0000e-07
# Epoch 31/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9665 - loss: 0.3283 - val_accuracy: 0.8115 - val_loss: 1.0791 - learning_rate: 1.0000e-07
# Epoch 32/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9679 - loss: 0.3269 - val_accuracy: 0.8117 - val_loss: 1.0791 - learning_rate: 1.0000e-07
# Epoch 33/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9678 - loss: 0.3277 - val_accuracy: 0.8121 - val_loss: 1.0786 - learning_rate: 1.0000e-07
# Epoch 34/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9657 - loss: 0.3333 - val_accuracy: 0.8122 - val_loss: 1.0796 - learning_rate: 1.0000e-07
# Epoch 35/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9662 - loss: 0.3310 - val_accuracy: 0.8120 - val_loss: 1.0795 - learning_rate: 1.0000e-07
# Epoch 36/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9657 - loss: 0.3317 - val_accuracy: 0.8114 - val_loss: 1.0794 - learning_rate: 1.0000e-07
# Epoch 37/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9668 - loss: 0.3305 - val_accuracy: 0.8125 - val_loss: 1.0793 - learning_rate: 1.0000e-07
# Epoch 38/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9674 - loss: 0.3296 - val_accuracy: 0.8124 - val_loss: 1.0783 - learning_rate: 1.0000e-07
# Epoch 39/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9668 - loss: 0.3300 - val_accuracy: 0.8125 - val_loss: 1.0781 - learning_rate: 1.0000e-07
# Epoch 40/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9657 - loss: 0.3322 - val_accuracy: 0.8115 - val_loss: 1.0802 - learning_rate: 1.0000e-07
# Epoch 41/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9673 - loss: 0.3284 - val_accuracy: 0.8119 - val_loss: 1.0787 - learning_rate: 1.0000e-07
# Epoch 42/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9678 - loss: 0.3293 - val_accuracy: 0.8124 - val_loss: 1.0792 - learning_rate: 1.0000e-07
# Epoch 43/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9665 - loss: 0.3291 - val_accuracy: 0.8116 - val_loss: 1.0802 - learning_rate: 1.0000e-07
# Epoch 44/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9669 - loss: 0.3289 - val_accuracy: 0.8121 - val_loss: 1.0794 - learning_rate: 1.0000e-07
# Epoch 45/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9672 - loss: 0.3263 - val_accuracy: 0.8120 - val_loss: 1.0810 - learning_rate: 1.0000e-07
# Epoch 46/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9689 - loss: 0.3257 - val_accuracy: 0.8122 - val_loss: 1.0802 - learning_rate: 1.0000e-07
# Epoch 47/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9663 - loss: 0.3329 - val_accuracy: 0.8128 - val_loss: 1.0789 - learning_rate: 1.0000e-07
# Epoch 48/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9664 - loss: 0.3288 - val_accuracy: 0.8125 - val_loss: 1.0805 - learning_rate: 1.0000e-07
# Epoch 49/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9652 - loss: 0.3298 - val_accuracy: 0.8118 - val_loss: 1.0799 - learning_rate: 1.0000e-07
# Epoch 50/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9686 - loss: 0.3256 - val_accuracy: 0.8123 - val_loss: 1.0809 - learning_rate: 1.0000e-07
